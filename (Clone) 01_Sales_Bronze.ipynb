# %%
# Sample Raw Sales Data Creation
sales_data = [
    (101, "Laptop", 50000, "2026-09-01"),
    (102, "Mobile", 20000, "2026-09-02"),
    (103, "Tablet", 15000, "2026-09-02")
]
schema = ["sale_id", "product_name", "amount", "sale_date"]

df_sales_raw = spark.createDataFrame(sales_data, schema=schema)

# Delta Table ga save cheyadam
df_sales_raw.write.format("delta").mode("overwrite").saveAsTable("sales_bronze")
print("🥉 Sales Bronze Table Created Successfully!")
# Out:
# 🥉 Sales Bronze Table Created Successfully!
